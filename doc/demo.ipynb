# %% [markdown]
# ### DEMO

# %%
# %matplotlib inline
import quandl
quandl.ApiConfig.api_key  = 'j5enkUXoa4uzZWPa3ee9'
#mydata = quandl.get("FRED/GDP")

# %%
mydata

# %%
a = quandl.get("BNC3/GWA_BTC")
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a['Close'].plot()

# %%
quandl.get("BNC3/GWA_BTC")
# Out:
#                    Open         High          Low        Close         Volume  \
# Date
# 2014-04-01   467.276162   488.622626   467.276162   479.562538   74776.478845
# 2014-04-02   479.196709   494.297933   431.318029   437.078735  114052.961126
# 2014-04-03   437.326535   449.738094   414.406179   445.597038   91415.080177
# 2014-04-04   445.179603   456.100459   429.161507   449.811259   51147.272019
# 2014-04-05   450.080200   464.088148   445.160655   461.695075   28449.194543
# 2014-04-06   463.180180   469.171431   451.129491   461.021853   21720.644202
# 2014-04-07   461.840024   464.272970   445.426509   452.901775   34949.203009
# 2014-04-08   450.065024   462.726648   447.960451   452.898545   24290.137840
# 2014-04-09   454.861445   464.369202   442.962551   449.302095   30135.245764
# 2014-04-10   449.717138   449.717138   358.701839   366.765666  149892.250029
# 2014-04-11   364.254104   430.128966   349.199527   421.787204  151050.949758
# ...
